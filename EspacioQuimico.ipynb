# %% [markdown]
# <a href="https://colab.research.google.com/github/sbolivara16/RdkitTools/blob/main/EspacioQuimico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌌🧪 Explorando el Espacio Químico con PCA: Una Perspectiva Profunda 🧬🚀
#
# ¡Bienvenidos a esta emocionante inmersión en el fascinante mundo del Espacio Químico! En este cuaderno, no solo exploraremos qué es el Espacio Químico, por qué es valioso y los Componentes Principales, sino que también profundizaremos en los tipos de descriptores que puedes calcular para comprender mejor las moléculas y compuestos químicos.
#
# ## 🔬 ¿Qué es el Espacio Químico?
#
# El Espacio Químico es un concepto asombroso que se asemeja a un vasto universo de moléculas y compuestos químicos. En este espacio abstracto, cada molécula se representa como un punto único. Sin embargo, a diferencia de las estrellas en el cielo, estos puntos se definen por una multitud de características químicas. Esto significa que dos moléculas cercanas en el Espacio Químico comparten similitudes químicas, mientras que las moléculas distantes presentan diferencias notables.
#
# Este espacio tridimensional, aunque abstracto, es esencial para la química computacional, la quimioinformática y la investigación de materiales. Es el lugar donde los científicos exploran virtualmente, descubren compuestos y aceleran el proceso de diseño de fármacos y desarrollo de materiales.
#
# ## 💡 ¿Por qué es útil el Espacio Químico?
#
# Imagina que eres un estudiante de doctorado investigando nuevas moléculas para aplicaciones farmacéuticas. En lugar de realizar innumerables experimentos en el laboratorio, puedes utilizar el Espacio Químico para navegar y encontrar compuestos químicos con propiedades similares a los que ya conoces. Esto ahorra tiempo, recursos y reduce el riesgo asociado con la síntesis y pruebas experimentales.
#
# Además, el Espacio Químico no solo es útil para encontrar moléculas similares, sino que también revela patrones y relaciones entre moléculas, lo que lleva a una comprensión más profunda de la química subyacente.
#
# ## 📊 Tipos de Descriptores Químicos
#
# Para comprender verdaderamente el Espacio Químico, es esencial considerar los descriptores químicos. Estos son parámetros numéricos que caracterizan las moléculas y permiten su representación en el Espacio Químico. Los descriptores pueden ser de diversos tipos, como:
#
# 1. **Descriptores Físico-Químicos**: Incluyen propiedades como el peso molecular, el punto de fusión, la solubilidad y la polaridad, que son cruciales para comprender cómo interactúan las moléculas en el mundo real.
#
# 2. **Descriptores Estructurales**: Se centran en la topología y la conectividad de átomos, lo que resulta fundamental para comprender las similitudes estructurales entre moléculas.
#
# 3. **Descriptores Cuánticos**: Profundizan en la química cuántica y ofrecen información sobre la energía, la densidad electrónica y otras características fundamentales de las moléculas.
#
# 4. **Descriptores Biológicos**: Relevantes para aplicaciones farmacéuticas, estos descriptores se enfocan en cómo las moléculas interactúan con sistemas biológicos, como proteínas o enzimas.
#
# ## 📈 Los Componentes Principales (PCA)
#
# Cuando hablamos del Espacio Químico, es esencial mencionar los "Componentes Principales" o PCA. Estas son transformaciones lineales que ayudan a simplificar y visualizar el Espacio Químico. En lugar de trabajar con miles de características químicas, el PCA nos permite identificar direcciones principales que explican la mayor variabilidad entre las moléculas.
#
# En resumen, el PCA es como un faro que ilumina las relaciones químicas en el vasto Espacio Químico, lo que nos permite comprender mejor cómo las moléculas interactúan y se relacionan.
#
# Este cuaderno de Google Colab será tu guía en esta emocionante exploración del Espacio Químico y los Componentes Principales. ¡Prepárate para un viaje científico de descubrimiento y comprensión! 🚀🔬👩‍🔬👨‍🔬
#
#
# ![image.png](data:image/png;base64,...)
#
# 🎯 ¿Cómo Interpretar un Gráfico de PCA?
#
# Un gráfico de PCA suele representar moléculas como puntos en un espacio bidimensional o tridimensional, donde los ejes están definidos por los Componentes Principales. Aquí hay algunas pautas para interpretarlo:
#
# Proximidad de Puntos: Dos puntos cercanos en el gráfico representan moléculas que comparten similitudes químicas. Esto puede indicar que tienen propiedades químicas similares o estructuras relacionadas.
#
# Distancia entre Puntos: Cuanto más distantes estén dos puntos, mayor será la diferencia en sus características químicas. Esto puede sugerir que estas moléculas son químicamente distintas.
#
# Dirección de los Puntos: La orientación de los puntos con respecto a los ejes del gráfico puede revelar patrones adicionales. Por ejemplo, si las moléculas se alinean en una dirección particular, podría indicar una tendencia química específica.
#
# 🧐 Ejemplo de Interpretación
#
# Supongamos que observamos un gráfico de PCA donde las moléculas de fármacos A y B están próximas en el espacio, mientras que el fármaco C está alejado. Esto podría sugerir que los fármacos A y B tienen similitudes químicas y podrían compartir propiedades farmacológicas, mientras que el fármaco C es químicamente diferente.
#
# En resumen, el gráfico de Componentes Principales es una poderosa herramienta que simplifica y visualiza el complejo Espacio Químico, permitiéndonos identificar similitudes, diferencias y patrones químicos de manera eficiente.
#
# ¡Ahora estás preparado para navegar y comprender el Espacio Químico como un verdadero científico! 🚀🔬🧑‍🔬👩‍🔬

# %% [markdown]
# **Iniciemos el trabajo en el cuaderno** ✈
#
# En esta celda, vamos a preparar nuestro entorno de trabajo para realizar emocionantes exploraciones en el mundo de la química computacional. 🧪💻 Para llevar a cabo estas investigaciones, vamos a utilizar algunas de las herramientas más poderosas en química y ciencia de datos.
#
# Primero, instalaremos el módulo RDKit, una biblioteca de química molecular que nos permitirá manipular y analizar moléculas en Python. RDKit es ampliamente utilizado en la industria farmacéutica y la investigación química.
#
# Luego, utilizaremos la biblioteca Padelpy para calcular una amplia variedad de descriptores moleculares. Los descriptores son características numéricas que representan diferentes propiedades químicas y físicas de las moléculas. Estos descriptores son esenciales para comprender la estructura y las propiedades de las moléculas. 📊🔍
#
# Finalmente, aprovecharemos RDKit para visualizar las moléculas que estamos estudiando. La visualización es una parte crucial de la química computacional, ya que nos permite ver las estructuras moleculares y comprender mejor sus características. 🖼️🔍
#
# En resumen, esta celda establecerá las bases para nuestras investigaciones en el campo de la química computacional. Estamos a punto de sumergirnos en el fascinante mundo de las moléculas y los datos químicos. ¡Comencemos nuestra exploración! 🚀🔬👩‍🔬👨‍🔬

# %%
# !pip install rdkit-pypi
# !pip install rdkit
# !pip install padelpy
from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
#  🌿🔬 A continuacion, utilizaremos una serie de bibliotecas y herramientas poderosas que nos permitirán analizar y visualizar estas valiosas moléculas.
#
# Primero, importaremos las librerías necesarias, incluyendo Pandas para el manejo de datos, RDKit para manipular moléculas y calcular descriptores, así como Scikit-Learn para realizar análisis de componentes principales (PCA). 📊🔍
#
# A continuación, crearemos una lista de 5 SMILES que representan moléculas de productos naturales. Los SMILES son una forma de codificar estructuras químicas en texto, lo que nos permitirá trabajar con ellas en Python. Estas moléculas incluyen compuestos como la aspirina, la cafeína y la morfina. 🍃☕💊
#
# Luego, calcularemos una serie de descriptores moleculares, como el peso molecular y el número de átomos, que nos ayudarán a caracterizar estas moléculas. Los descriptores son como huellas dactilares químicas que nos dirán más sobre las propiedades de estas sustancias naturales. 🧬🔍
#
# Después, escalaremos estos descriptores para asegurarnos de que tengan la misma escala, lo que facilitará su comparación y análisis. 📏
#
# El siguiente paso es el análisis de componentes principales (PCA), que nos permitirá reducir la dimensionalidad de nuestros datos y visualizar las relaciones entre estas moléculas en un espacio bidimensional. 📊✨
#
# Finalmente, presentaremos los resultados en una tabla formateada para una fácil interpretación. Así, podrás apreciar las similitudes y diferencias entre estas moléculas de productos naturales de manera clara y efectiva. 📈🧐

# %%
# Importar librerías
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Lista de 5 SMILES de productos naturales de ejemplo
smiles_list = [
    "CC(=O)OC1=CC=CC=C1C(=O)O",  # Aspirina
    "CN1C=NC2=C1C(=O)N(C(=O)N2C)C",  # Cafeína
    "CN1CCC23C4C1CC5=C2C(=C(C=C5)O)OC3C4",  # Morfina
    "CN1C2=CC=CC=C2C(=O)C3=C1C=CC(=C3)OC",  # Quinina
    "C1=CC(=C(C=C1O)O)C=CC2=CC(=C(C=C2)O)O"  # Resveratrol
]

data = pd.DataFrame({'SMILES': smiles_list})

# Calcular los descriptores moleculares (peso molecular, número de átomos)
molecules = [Chem.MolFromSmiles(smiles) for smiles in data['SMILES']]
data['MolecularWeight'] = [Descriptors.MolWt(mol) for mol in molecules]
data['NumAtoms'] = [mol.GetNumAtoms() for mol in molecules]

# Escalar los descriptores
scaler = StandardScaler()
data[['MolecularWeight', 'NumAtoms']] = scaler.fit_transform(data[['MolecularWeight', 'NumAtoms']])

# Calcular PCA con 2 componentes principales
n_components = 2
pca = PCA(n_components=n_components)

principal_components = pca.fit_transform(data[['MolecularWeight', 'NumAtoms']])

# Crear nuevas columnas con los componentes principales (PC1 y PC2)
data['PC1'] = principal_components[:, 0]
data['PC2'] = principal_components[:, 1]

# Mostrar el DataFrame con los datos formateados
from tabulate import tabulate

headers = ['SMILES', 'MolecularWeight', 'PC1', 'PC2']
table = data[['SMILES', 'MolecularWeight', 'PC1', 'PC2']].values
formatted_table = tabulate(table, headers, tablefmt='grid')

print(formatted_table)
# Out:
# +---------------------------------------+-------------------+----------+------------+
# | SMILES                                |   MolecularWeight |      PC1 |        PC2 |
# +=======================================+===================+==========+============+
# | CC(=O)OC1=CC=CC=C1C(=O)O              |         -1.46233  |  2.05002 |  0.0180192 |
# +---------------------------------------+-------------------+----------+------------+
# | CN1C=NC2=C1C(=O)N(C(=O)N2C)C          |         -0.950215 |  1.3704  | -0.0265971 |
# +---------------------------------------+-------------------+----------+------------+
# | CN1CCC23C4C1CC5=C2C(=C(C=C5)O)OC3C4   |          0.841787 | -1.16673 | -0.0237329 |
# +---------------------------------------+-------------------+----------+------------+
# | CN1C2=CC=CC=C2C(=O)C3=C1C=CC(=C3)OC   |          0.694667 | -1.0627  |  0.0802966 |
# +---------------------------------------+-------------------+----------+------------+
# ...

# %% [markdown]
# 🌿📈 En esta celda, daremos vida a nuestros datos y los transformaremos en un hermoso gráfico de dispersión 2D que revelará las relaciones químicas y estructurales entre las moléculas que hemos estado investigando. 📊✨
#
# Primero, importaremos la librería de trazado (Matplotlib) y configuraremos el tamaño de nuestra futura obra maestra visual. Luego, aprovechando los Componentes Principales (PC1 y PC2) que calculamos previamente, crearemos un gráfico de dispersión que representa nuestras moléculas en este espacio reducido. Cada punto en el gráfico corresponderá a una molécula, y su posición relativa revelará información crucial sobre sus similitudes y diferencias químicas. 🌐🔍
#
# Las coordenadas en el eje X (PC1) y en el eje Y (PC2) serán como las coordenadas de un mapa químico que exploraremos juntos. La proximidad de los puntos indicará similitudes, mientras que la distancia revelará diferencias químicas. ¿Notas alguna tendencia o agrupamiento de puntos?  🗺️🧭🌐

# %%
# Visualizar los componentes principales en un gráfico de dispersión 2D
plt.figure(figsize=(8, 6))
plt.scatter(data['PC1'], data['PC2'], c='blue', alpha=0.5)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Gráfico de Componentes Principales (PC1 vs PC2)')
plt.grid(True)
plt.show()

# %% [markdown]
# Hasta ahora, hemos explorado el Espacio Químico utilizando **el peso molecular y el número de átomo**s como nuestros descriptores principales. Si bien estos son descriptores fundamentales, el vasto mundo de la química tiene mucho más que ofrecer. 🌌🧪
#
#
# Algunos ejemplos de descriptores adicionales que podríamos considerar incluir son:
#
# **LogP (Coeficiente de Partición Octanol-Agua)**: Este descriptor informa sobre la lipofilicidad de una molécula, lo que es crucial en la absorción y distribución de fármacos en el cuerpo.
#
# **Polaridad**: La polaridad de una molécula puede influir en sus propiedades químicas y biológicas. Podemos calcular varios índices de polaridad.
#
# **Grupos Funcionales**: Identificar y contar grupos funcionales específicos puede revelar información sobre la reactividad química.
#
# **Propiedades Termodinámicas**: Descriptores como el calor de formación estándar o la entropía pueden ayudarnos a comprender las energías implicadas en las reacciones químicas.
#
# **Dimensiones Estructurales**: Características estructurales más detalladas, como diámetros moleculares o momentos dipolares, también son útiles.
#
# La incorporación de estos descriptores adicionales puede proporcionar una visión más completa y sofisticada del Espacio Químico y permitirnos descubrir patrones y relaciones aún más interesantes.

# %% [markdown]
# **Si deseas explorar el Espacio Químico con descriptores adicionales y obtener un análisis más profundo, puedes seguir estos pasos para modificar el código:**

# %% [markdown]
# **TEN EN CUENTA LO SIGUIENTE**⚠️
#
# ***Si tu objetivo es añadir otro tipo de descriptores a tu estudio. En el siguiente comando es fundamental que lo modifiques a tu conveniencia. El código está hecho para calcular logP, pero, por ejemplo, si quieres calcular polaridad, el código quedaría de la siguiente manera***:
#
#
#
# ![image.png](data:image/png;base64,...)
#
# Si tu objetivo es calcular grupos funcionales como: (Número de Átomos de Hidrógeno y Donadores de Enlaces de Hidrógeno), el codigo quedaria de la siguiente forma:
#
# ![image.png](data:image/png;base64,...)
#
# Si tu objetivo es calcular propiedades termodinamicas como punto de fusion, el codigo quedaria de la siguiente forma:
#
# ![image.png](data:image/png;base64,...)
#
# Si tu objetivo es calcular dimensiones estructurales como numero de Número de Átomos y Enlaces, el codigo quedaria asi:
#
# ![image.png](data:image/png;base64,...)

# %%
from rdkit.Chem import Crippen
data['LogP'] = [Crippen.MolLogP(mol) for mol in molecules]
scaler = StandardScaler()
data[['LogP']] = scaler.fit_transform(data[['LogP']])

# %%
# Actualizar el número de componentes principales
n_components = 3  # Cambia el número de componentes según sea necesario
pca = PCA(n_components=n_components)

# Actualizar los datos utilizados para el PCA
principal_components = pca.fit_transform(data[['MolecularWeight', 'NumAtoms', 'LogP']])

# %%
from rdkit import Chem
from rdkit.Chem import Crippen

# Función para calcular logP
def calcular_logP(mol):
    try:
        return Crippen.MolLogP(mol)
    except:
        return None

# Calcular el logP y agregarlo al DataFrame
data['logP'] = [calcular_logP(mol) for mol in molecules]

# %%
# Calcular el logP y agregarlo al DataFrame
data['logP'] = [calcular_logP(mol) for mol in molecules]

# Visualizar los componentes principales en un gráfico de dispersión 2D junto con logP
plt.figure(figsize=(8, 6))
plt.scatter(data['PC1'], data['PC2'], c='blue', alpha=0.5, label='PC1 vs PC2')
plt.scatter(data['PC1'], data['logP'], c='red', alpha=0.5, label='PC1 vs logP')
plt.xlabel('PC1')
plt.ylabel('Valor')
plt.title('Gráfico de Componentes Principales y logP')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ¡Ha sido un placer ayudarte en este recorrido por el fascinante mundo de las herramientas computacionales para la química! Esperamos que hayas disfrutado aprendiendo sobre cómo utilizar Python, RDKit y el análisis de Componentes Principales (PCA) para explorar el Espacio Químico.
#
# Recuerda que esto es solo el comienzo. La ciencia computacional y la química computacional ofrecen un vasto campo de posibilidades para investigaciones emocionantes y descubrimientos científicos. Te animamos a seguir explorando, investigando y aprendiendo sobre estas herramientas y técnicas.
#
# Siempre hay más por descubrir y comprender en el mundo de la química y la informática. ¡No dudes en sumergirte aún más en este emocionante viaje de conocimiento! ¡Hasta la próxima! 🚀🔬🧑‍🔬👩‍🔬
